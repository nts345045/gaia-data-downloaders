# %% [markdown]
# # USGS Stream Gage Site Metadata Downloader
# AUTH: Nathan T. Stevens
# ORG: Pacific Northwest Seismic Network
# LICENSE: GNU GPLv3
# PURPOSE: This notebook details how to get USGS surface water gage metadata (site information) from the WaterWatch dataservice.

# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import os

# %%
# USER PARAMETER BLOCK
# Define states to query and where to save the output
# Human readable list of USA state abbreviations
states = ['WA','OR']
# Where to save the file
PWD = Path().cwd()
SAVEDIR = PWD/'USGS_Stream_Gage'
# Create save path if it does not already exist
os.makedirs(SAVEDIR, exist_ok=True)

# END OF USER PARAMETER BLOCK

# %%
# Compose request URL for gauge site metadata
# Convert state list to URL format
states = ','.join(states).lower()
# Make request URL
URL = f'https://waterwatch.usgs.gov/download/?gt=map&mt=real&st={states}&dt=site&ht=&fmt=csv&mk=1'

# %%
# Submit request
df = pd.read_csv(URL, index_col='id')

# %%
# Parse `flowinfo` and `name` columns
_FI_HDRS = set(['Discharge (cfs)', 'Stage (ft)', 'Stage (adj) (ft)', 'Date', 'Length of record (years)', 'Class', '% normal(median) (%)', '% normal(mean) (%)', 'Status'])
holder = dict(zip(_FI_HDRS, [[] for _e in _FI_HDRS]))
idx = []
for id, row in df.iterrows():
    # Skip repeat header lines for multi-state query
    if id == 'id':
        continue
    # Catch station ID
    idx.append(id)

    # parse flowinfo
    fiparts = row.flowinfo.split(';')
    fi_claimed = set()
    for _e in fiparts:
        if 'Date' in _e:
            _k = _e[:4]
            _v = pd.Timestamp(_e[6:], tz='US/Pacific')
            holder[_k].append(_v)
            fi_claimed.add(_k)
            continue
        
        try:
            _k, _v = _e.split(':')
        except:
            breakpoint()
        _v = _v.strip()
        if _k in ['Class', 'Status']:
            pass
        else:
            _vp = _v.split(' ')
            try:
                _v = float(_vp[0])
            except:
                breakpoint()
            if _vp[1] != '%':
                _k += f' ({_vp[-1]})'
        holder[_k].append(_v)
        fi_claimed.add(_k)
    for _k, _v in holder.items():
        if len(_v) < len(idx):
            holder[_k].append(None)

dfp = pd.DataFrame(holder, index=idx)
df_parsed = df.join(dfp, how='left')
df_parsed.drop(columns=['flowinfo'], inplace=True)

# %%
# Display parsed site information & save to disk
display(df_parsed)
df_parsed.to_csv(SAVEDIR/'usgs_gauge_site_metadata.csv')
# Out:
#                                                          name          lat  \
# id
# 10352500          USGS 10352500 MCDERMITT CK NR MCDERMITT, NV  41.96655720
# 10387110    USGS 10387110 CHEWAUCAN RIVER AT MOUTH NEAR VA...  42.52208056
# 10387150       USGS 10387150 LAKE ABERT NEAR VALLEY FALLS, OR  42.60350000
# 10396000    USGS 10396000 DONNER UND BLITZEN RIVER NR FREN...  42.79083330
# 11491450             USGS 11491450 IRVING CREEK NEAR LENZ, OR  42.95166667
# ...                                                       ...          ...
# 14244180    USGS 14244180 COWLITZ RIVER NEAR 1ST AVE NW AT...  46.14722008
# 14246900    USGS 14246900 COLUMBIA RIVER AT PORT WESTWARD,...  46.18122136
# 14246900    USGS 14246900 COLUMBIA RIVER AT PORT WESTWARD,...  46.18122136
# 1203951610    USGS 1203951610 QUINAULT RIVER NEAR TAHOLAH, WA  47.35777778
# 1206250575  USGS 1206250575 WEAVER CREEK AT HWY 101 NEAR P...  47.30577220
#
#                       lng class  \
# id
# 10352500    -117.83181200     4
# 10387110    -120.24945000     0
# 10387150    -120.18730560     0
# 10396000    -118.86750000     5
# 11491450    -121.45905560     0
# ...                   ...   ...
# 14244180    -122.91605530     0
# 14246900    -123.18345390     5
# 14246900    -123.18345390     5
# 1203951610  -124.18444440     0
# 1206250575  -123.17883890     0
#
#                                                           url        huc_cd  \
# id
# 10352500    https://waterdata.usgs.gov/monitoring-location...      16040201
# 10387110    https://waterdata.usgs.gov/monitoring-location...  171200060506
# 10387150    https://waterdata.usgs.gov/monitoring-location...      17120006
# 10396000    https://waterdata.usgs.gov/monitoring-location...      17120003
# 11491450    https://waterdata.usgs.gov/monitoring-location...      18010201
# ...                                                       ...           ...
# 14244180    https://waterdata.usgs.gov/monitoring-location...           NaN
# 14246900    https://waterdata.usgs.gov/monitoring-location...      17080003
# 14246900    https://waterdata.usgs.gov/monitoring-location...      17080003
# 1203951610  https://waterdata.usgs.gov/monitoring-location...      17100102
# 1206250575  https://waterdata.usgs.gov/monitoring-location...      17110017
#
#             Stage (ft)  Discharge (cfs)       Class  Length of record (years)  \
# id
# 10352500          2.23             3.77       10-24                      74.0
# 10387110          8.52              NaN  Not-ranked                       NaN
# 10387150       4253.30              NaN  Not-ranked                       NaN
# 10396000          1.99            50.50       25-75                      94.0
# 11491450         19.71             0.92  Not-ranked                       NaN
# ...                ...              ...         ...                       ...
# 14244180         10.79              NaN  Not-ranked                       NaN
# 14246900          8.24        211000.00       25-75                      34.0
# 14246900          8.24        211000.00       25-75                      34.0
# 1203951610        9.97         15300.00  Not-ranked                       6.0
# 1206250575       11.77              NaN  Not-ranked                       1.0
#
#                                 Date  % normal(median) (%)  \
# id
# 10352500   2025-12-15 12:00:00-08:00                 49.93
# 10387110   2025-12-15 12:00:00-08:00                   NaN
# 10387150   2025-12-15 12:45:00-08:00                   NaN
# 10396000   2025-12-15 12:00:00-08:00                120.24
# 11491450   2025-12-15 12:30:00-08:00                   NaN
# ...                              ...                   ...
# 14244180   2025-09-08 12:15:00-07:00                   NaN
# 14246900   2025-12-15 12:40:00-08:00                 92.14
# 14246900   2025-12-15 12:40:00-08:00                 92.14
# 1203951610 2025-12-15 12:15:00-08:00                400.00
# 1206250575 2025-12-15 12:30:00-08:00                   NaN
#
#             % normal(mean) (%) Status  Stage (adj) (ft)
# id
# 10352500                 28.54   None           4547.23
# 10387110                   NaN   None               NaN
# 10387150                   NaN   None           4253.30
# 10396000                 90.19   None           4262.32
# 11491450                   NaN   None           4636.71
# ...                        ...    ...               ...
# 14244180                   NaN   None             10.79
# 14246900                 82.78   None              7.24
# 14246900                 82.78   None              7.24
# 1203951610              293.95   None             81.97
# 1206250575                 NaN   None             25.76
#
# [743 rows x 15 columns]
